# %%
# The draft GUI of Search Engine
import tkinter as tk
from tkinter import ttk

# 创建主窗口
root = tk.Tk()
root.title("Search Engine")

# 创建输入框
entry = tk.Entry(root, width=50)
entry.pack(pady=10)

# 创建标题标签（初始隐藏）
title_label = tk.Label(root, text="", font=("Arial", 14, "bold"))
title_label.pack(pady=5)
title_label.pack_forget()

# 定义表格变量
tree = None  
user_query = "" # 存储用户输入

# mock the result of search engine
def mock_search_engine(query):
    return {
        f"related text {i}": round(1 - i * 0.1, 2)  # 生成相关度递减的示例数据
        for i in range(1, 11)  # 生成10个文本
    }

# 按钮回调函数
def on_search(event=None):
    global tree, user_query  
    user_query = entry.get().strip()  

    if not user_query:  # 避免空输入
        return

    # 调用搜索引擎（这里用 mock_search_engine 代替）
    search_results = mock_search_engine(user_query)

    # 设置标题并显示
    title_label.config(text=f"『The result of search {user_query}』")
    title_label.pack()

    # 如果表格已存在，先删除
    if tree:
        tree.destroy()

    # 创建 Treeview 表格
    columns = ("Order", "Text", "Similarity")
    tree = ttk.Treeview(root, columns=columns, show="headings")

    # 设置列标题
    tree.heading("Order", text="Order")
    tree.heading("Text", text="Text")
    tree.heading("Similarity", text="Similarity")

    # 设置列的宽度
    tree.column("Order", width=50, anchor="center")
    tree.column("Text", width=200, anchor="w")
    tree.column("Similarity", width=100, anchor="center")

    # 插入搜索结果
    for idx, (text, similarity) in enumerate(search_results.items(), start=1):
        tree.insert("", "end", values=(idx, text, similarity))

    tree.pack(pady=10)

    print(f"The user query is: {user_query}")  # 调试用

# 创建按钮
button = tk.Button(root, text="Search", command=on_search)
button.pack(pady=10)

# 绑定回车键
root.bind("<Return>", on_search)

# 运行 GUI
root.mainloop()

# %%
# download PyTerrier
# !pip install python-terrier
# Out:
# Requirement already satisfied: python-terrier in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (0.13.0)
# Requirement already satisfied: numpy in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from python-terrier) (2.1.2)
# Requirement already satisfied: pandas in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from python-terrier) (2.2.3)
# Requirement already satisfied: more-itertools in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from python-terrier) (10.6.0)
# Requirement already satisfied: tqdm in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from python-terrier) (4.66.6)
# Requirement already satisfied: requests in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from python-terrier) (2.32.3)
# Requirement already satisfied: ir-datasets>=0.3.2 in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from python-terrier) (0.5.10)
# Requirement already satisfied: wget in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from python-terrier) (3.2)
# Requirement already satisfied: pyjnius>=1.4.2 in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from python-terrier) (1.6.1)
# Requirement already satisfied: deprecated in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from python-terrier) (1.2.18)
# Requirement already satisfied: scipy in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from python-terrier) (1.14.1)
# Requirement already satisfied: ir-measures>=0.3.1 in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from python-terrier) (0.3.7)
# Requirement already satisfied: pytrec-eval-terrier>=0.5.3 in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from python-terrier) (0.5.6)
# Requirement already satisfied: jinja2 in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from python-terrier) (3.1.4)
# Requirement already satisfied: statsmodels in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from python-terrier) (0.14.4)
# Requirement already satisfied: dill in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from python-terrier) (0.3.9)
# Requirement already satisfied: joblib in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from python-terrier) (1.4.2)
# Requirement already satisfied: chest in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from python-terrier) (0.2.3)
# Requirement already satisfied: lz4 in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from python-terrier) (4.4.3)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from ir-datasets>=0.3.2->python-terrier) (4.12.3)
# Requirement already satisfied: inscriptis>=2.2.0 in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from ir-datasets>=0.3.2->python-terrier) (2.5.3)
# Requirement already satisfied: lxml>=4.5.2 in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from ir-datasets>=0.3.2->python-terrier) (5.3.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from ir-datasets>=0.3.2->python-terrier) (6.0.1)
# Requirement already satisfied: trec-car-tools>=2.5.4 in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from ir-datasets>=0.3.2->python-terrier) (2.6)
# Requirement already satisfied: warc3-wet>=0.2.3 in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from ir-datasets>=0.3.2->python-terrier) (0.2.5)
# Requirement already satisfied: warc3-wet-clueweb09>=0.2.5 in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from ir-datasets>=0.3.2->python-terrier) (0.2.5)
# Requirement already satisfied: zlib-state>=0.1.3 in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from ir-datasets>=0.3.2->python-terrier) (0.1.9)
# Requirement already satisfied: ijson>=3.1.3 in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from ir-datasets>=0.3.2->python-terrier) (3.3.0)
# Requirement already satisfied: unlzw3>=0.2.1 in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from ir-datasets>=0.3.2->python-terrier) (0.2.3)
# Requirement already satisfied: pyarrow>=16.1.0 in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from ir-datasets>=0.3.2->python-terrier) (19.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from requests->python-terrier) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from requests->python-terrier) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from requests->python-terrier) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from requests->python-terrier) (2024.7.4)
# Requirement already satisfied: colorama in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from tqdm->python-terrier) (0.4.6)
# Requirement already satisfied: heapdict in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from chest->python-terrier) (1.0.1)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from deprecated->python-terrier) (1.17.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from jinja2->python-terrier) (2.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from pandas->python-terrier) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from pandas->python-terrier) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from pandas->python-terrier) (2024.2)
# Requirement already satisfied: patsy>=0.5.6 in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from statsmodels->python-terrier) (1.0.1)
# Requirement already satisfied: packaging>=21.3 in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from statsmodels->python-terrier) (24.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from beautifulsoup4>=4.4.1->ir-datasets>=0.3.2->python-terrier) (2.5)
# Requirement already satisfied: six>=1.5 in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas->python-terrier) (1.16.0)
# Requirement already satisfied: cbor>=1.0.0 in c:\users\郭丁恺\appdata\local\programs\python\python312\lib\site-packages (from trec-car-tools>=2.5.4->ir-datasets>=0.3.2->python-terrier) (1.0.0)
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pyterrier as pt
import pandas as pd

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# Downlaod resources
nltk.download("punkt")
nltk.download("stopwords")
stop_words = set(stopwords.words("english"))

# Define Preprocess function
def preprocess(text):    
    # Lowercase
    text = text.lower()
    
    # tokennization
    words = word_tokenize(text)
    
    # remove stopwords
    filtered_words = [word for word in words if word not in stop_words]
    
    # connect the result
    return " ".join(filtered_words)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\郭丁恺\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\郭丁恺\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# The original dataset
df = pd.read_csv("Reuter_test.csv")
df.head(10)
# Out:
#                                                 text text_type  \
# 0  Mounting trade friction between the\nU.S. And ...    "NORM"
# 1  A survey of 19 provinces and seven cities\nsho...    "NORM"
# 2  The Ministry of International Trade and\nIndus...    "NORM"
# 3  Thailand's trade deficit widened to 4.5\nbilli...    "NORM"
# 4  Indonesia expects crude palm oil (CPO)\nprices...    "NORM"
# 5                                                NaN   "BRIEF"
# 6  Tug crews in New South Wales (NSW),\nVictoria ...    "NORM"
# 7  The Indonesian Commodity Exchange is\nlikely t...    "NORM"
# 8  Food Department officials said the U.S.\nDepar...    "NORM"
# 9  Western Mining Corp Holdings Ltd\n&lt;WMNG.S> ...    "NORM"
#
#                                               topics lewis_split  \
# 0                                          ['trade']      "TEST"
# 1                                          ['grain']      "TEST"
# 2                                ['crude' 'nat-gas']      "TEST"
# 3  ['trade' 'grain' 'rice' 'corn' 'sugar' 'tin' '...      "TEST"
# 4                             ['veg-oil' 'palm-oil']      "TEST"
# 5                                                 []      "TEST"
# 6                                           ['ship']      "TEST"
# 7  ['veg-oil' 'palm-oil' 'lumber' 'coffee' 'rubber']      "TEST"
# 8                                  ['grain' 'wheat']      "TEST"
# 9                                           ['gold']      "TEST"
#
#        cgis_split  old_id   new_id  \
# 0  "TRAINING-SET"  "3809"  "14826"
# 1  "TRAINING-SET"  "3811"  "14828"
# 2  "TRAINING-SET"  "4356"  "14829"
# 3  "TRAINING-SET"  "3815"  "14832"
# 4  "TRAINING-SET"  "3816"  "14833"
# 5  "TRAINING-SET"  "3818"  "14835"
# 6  "TRAINING-SET"  "3822"  "14839"
# 7  "TRAINING-SET"  "4358"  "14840"
# 8  "TRAINING-SET"  "3824"  "14841"
# 9  "TRAINING-SET"  "3825"  "14842"
#
#                                               places people orgs exchanges  \
# 0  ['hong-kong' 'usa' 'japan' 'taiwan' 'malaysia'...     []   []        []
# 1                                          ['china']     []   []        []
# 2                                          ['japan']     []   []        []
# 3                                       ['thailand']     []   []        []
# 4                           ['indonesia' 'malaysia']     []   []        []
# 5                                                 []     []   []        []
# 6                                      ['australia']     []   []        []
# 7               ['indonesia' 'south-korea' 'taiwan']     []   []        []
# 8                                ['sri-lanka' 'usa']     []   []        []
# 9                                      ['australia']     []   []        []
#
#                       date                                              title
# 0   8-APR-1987 01:03:47.52   ASIAN EXPORTERS FEAR DAMAGE FROM U.S.-JAPAN RIFT
# 1   8-APR-1987 01:19:17.29  CHINA DAILY SAYS VERMIN EAT 7-12 PCT GRAIN STOCKS
# 2   8-APR-1987 01:22:17.25  JAPAN TO REVISE LONG-TERM ENERGY DEMAND DOWNWARDS
# 3   8-APR-1987 01:45:09.09         THAI TRADE DEFICIT WIDENS IN FIRST QUARTER
# 4   8-APR-1987 01:48:20.11            INDONESIA SEES CPO PRICE RISING SHARPLY
# 5   8-APR-1987 02:11:57.43  Japan four-year note auction average yield rec...
# 6   8-APR-1987 02:42:14.86  AUSTRALIAN FOREIGN SHIP BAN ENDS BUT NSW PORTS...
# 7   8-APR-1987 02:56:07.22           INDONESIAN COMMODITY EXCHANGE MAY EXPAND
# 8   8-APR-1987 03:09:59.77       SRI LANKA GETS USDA APPROVAL FOR WHEAT PRICE
# 9   8-APR-1987 03:21:39.74  WESTERN MINING TO OPEN NEW GOLD MINE IN AUSTRALIA

# %%
# Load the preprocessed dataset
# Load the dataset with selected column
df = pd.read_csv("Reuter_test.csv", usecols=["title","text","old_id"])
df.rename(columns = {"old_id": "docno"}, inplace = True)
new_order = ["docno", "title", "text"]
df = df[new_order]

# drop the data which its text is NaN 
df = df.dropna(subset=["text","title"])

# Preprocess the text and title field
df['text'] = df['text'].apply(preprocess)
df['title'] = df['title'].apply(preprocess)
# Save cleaned dataset 
df.to_csv("cleaned_dataset.csv")

# Display first 10 data
df.head(10)
# Out:
#      docno                                              title  \
# 0   "3809"        asian exporters fear damage u.s.-japan rift
# 1   "3811"  china daily says vermin eat 7-12 pct grain stocks
# 2   "4356"     japan revise long-term energy demand downwards
# 3   "3815"            thai trade deficit widens first quarter
# 4   "3816"            indonesia sees cpo price rising sharply
# 6   "3822"     australian foreign ship ban ends nsw ports hit
# 7   "4358"           indonesian commodity exchange may expand
# 8   "3824"           sri lanka gets usda approval wheat price
# 9   "3825"        western mining open new gold mine australia
# 10  "3826"           sumitomo bank aims quick recovery merger
#
#                                                  text
# 0   mounting trade friction u.s. japan raised fear...
# 1   survey 19 provinces seven cities showed vermin...
# 2   ministry international trade industry ( miti )...
# 3   thailand 's trade deficit widened 4.5 billion ...
# 4   indonesia expects crude palm oil ( cpo ) price...
# 6   tug crews new south wales ( nsw ) , victoria w...
# 7   indonesian commodity exchange likely start tra...
# 8   food department officials said u.s. department...
# 9   western mining corp holdings ltd & lt ; wmng.s...
# 10  sumitomo bank ltd & lt ; sumi.t > certain lose...

# %%
# index
df = pd.read_csv("cleaned_dataset.csv")

# 确保 CSV 包含 'docno' 和 'text' 两列
if 'docno' not in df.columns or 'text' not in df.columns:
    raise ValueError("CSV 文件必须包含 'docno' 和 'text' 两列")

# 将 DataFrame 转换为可迭代字典格式
doc_iter = df.to_dict(orient="records")

# 创建索引器
indexer = pt.IterDictIndexer("./index", meta={'docno': 20, 'text': 4096})

# 生成索引
indexref = indexer.index(doc_iter)

# 加载索引并打印统计信息
index = pt.IndexFactory.of(indexref)
print(index.getCollectionStatistics().toString())
# Out:
# ---------------------------------------------------------------------------
# JavaException                             Traceback (most recent call last)
# Cell In[6], line 12
#       9 doc_iter = df.to_dict(orient="records")
#      11 # 创建索引器
# ---> 12 indexer = pt.IterDictIndexer("./index", meta={'docno': 20, 'text': 4096})
#      14 # 生成索引
#      15 indexref = indexer.index(doc_iter)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyterrier\terrier\index.py:557, in _BaseIterDictIndexer.__init__(self, index_path, meta, text_attrs, meta_reverse, pretokenised, fields, threads, **kwargs)
#     544 """
#     545
#     546 Args:
#    (...)
#     554     kwargs: Additional keyword arguments passed to TerrierIndexer.
#     555 """
#     556 pt.Indexer.__init__(self)
# --> 557 TerrierIndexer.__init__(self, index_path, **kwargs)
#     559 assert pt.terrier.check_version("5.11"), "Terrier 5.11 is required"
#     561 self.threads = threads
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyterrier\utils.py:207, in pre_invocation_decorator.<locals>._decorator_wrapper.<locals>._wrapper(*args, **kwargs)
#     205 @wraps(fn)
#     206 def _wrapper(*args, **kwargs):
# --> 207     decorator(fn)
#     208     return fn(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyterrier\java\_utils.py:35, in required(fn)
#      33 if not _started:
#      34     trigger = fn.__qualname__ if hasattr(fn, '__qualname__') else fn.__name__
# ---> 35     _init(trigger=trigger)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyterrier\utils.py:94, in once.<locals>._once.<locals>._wrapper(*args, **kwargs)
#      92     raise ValueError(f"{fn.__name__} has already been run")
#      93 # how to handle errors?
# ---> 94 res = fn(*args, **kwargs)
#      95 called = True
#      96 return res
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyterrier\java\_utils.py:133, in _init(trigger)
#     131 # run post-initialization setup
#     132 for _, initializer in initializers:
# --> 133     initializer.post_init(jnius)
#     135 # build "Java started" message
#     136 message = []
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyterrier\java\_utils.py:45, in required_raise.<locals>._wrapper(*args, **kwargs)
#      43 if not started():
#      44     raise RuntimeError(f'You need to call pt.java.init() required before you can call {fn}')
# ---> 45 return fn(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyterrier\java\_core.py:67, in CoreJavaInit.post_init(self, jnius)
#      65 @required_raise
#      66 def post_init(self, jnius):
# ---> 67     pt.java.set_log_level(pt.java.configure['log_level'])
#      69     if pt.java.configure['redirect_io']:
#      70         pt.java.redirect_stdouterr()
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyterrier\java\_core.py:229, in set_log_level(level)
#     227     configure['log_level'] = level
#     228 else:
# --> 229     J.PTUtils.setLogLevel(level, None)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyterrier\java\_utils.py:45, in required_raise.<locals>._wrapper(*args, **kwargs)
#      43 if not started():
#      44     raise RuntimeError(f'You need to call pt.java.init() required before you can call {fn}')
# ---> 45 return fn(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyterrier\java\_utils.py:398, in JavaClasses.__getattr__(self, key)
#     396     if callable(clz):
#     397         clz = clz()
# --> 398     self._cache[key] = pt.java.autoclass(clz)
#     399 return self._cache[key]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyterrier\java\_utils.py:45, in required_raise.<locals>._wrapper(*args, **kwargs)
#      43 if not started():
#      44     raise RuntimeError(f'You need to call pt.java.init() required before you can call {fn}')
# ---> 45 return fn(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyterrier\java\_utils.py:75, in autoclass(*args, **kwargs)
#      71 """
#      72 Wraps jnius.autoclass once java has started. Raises an error if called before pt.java.init() is called.
#      73 """
#      74 import jnius # noqa: PT100
# ---> 75 return jnius.autoclass(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\jnius\reflect.py:209, in autoclass(clsname, include_protected, include_private)
#     206 cls_start_packagename = '.'.join(clsname.split('.')[:-1])
#     208 # c = Class.forName(clsname)
# --> 209 c = find_javaclass(clsname)
#     210 if c is None:
#     211     raise Exception('Java class {0} not found'.format(c))
#
# File jnius\\jnius_export_func.pxi:22, in jnius.find_javaclass()
#
# File jnius\\jnius_utils.pxi:79, in jnius.check_exception()
#
# JavaException: JVM exception occurred: org/terrier/python/PTUtils java.lang.NoClassDefFoundError
